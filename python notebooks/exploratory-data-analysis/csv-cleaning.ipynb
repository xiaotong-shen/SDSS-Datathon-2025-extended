# %%
import pandas as pd
df = pd.read_csv('./Transportation-Data/subway-data.csv')

df_cleaned = df[~df['Station'].str.contains(' to ', case=False)].copy()

# checking numnber of unique stations
unique_stations = sorted(df_cleaned['Station'].unique())
for station in unique_stations:
    print(station)
print(len(unique_stations))

unique_stations = pd.DataFrame(unique_stations, columns=['Column_Name'])


unique_stations.to_csv('./Transportation-Data/unique_stations.csv', index=False)
# Out:
# (APPROACHING) KENNEDY
# 111 SPADINA ROAD
# 1900 YONGE MCBRIEN BLD
# 1900 YONGE ST- MCBRIEN
# 2233 SHEPPARD WEST
# ALL STATIONS
# APPROACHING DUNDAS WES
# ASQUITH SUBSTATION
# BATHURST STATION
# BAY LOWER
# BAY STATION
# BAYVIEW STATION
# BESSARION STATION
# BETWEEN WARDEN STATION
# BLOOR / DANFORTH LINE
# BLOOR DANFORTH LINE
# BLOOR DANFORTH LINE 2
# BLOOR DANFORTH SUBWAY
# BLOOR SATION
# BLOOR STATION
# BLOOR STATION - YONGE
# BROADVIEW AND ST GEORG
# BROADVIEW CENTRE TRACK
# BROADVIEW STATION
# BUCHAN ESB
# CASTLE FRANK STATION
# CHANGE OVERS
# CHANGE OVERS LINE TWO
# CHESTER STATION
# CHRISTIE CENTRE TRACK
# CHRISTIE STATION
# CHRISTIE STATION (LEAV
# COLLEGE AND OSGOODE ST
# COLLEGE STATION
# COXWELL STATION
# DANFORTH DIVISION
# DAVISVILLE BUILD UP
# DAVISVILLE BUILD-UP
# DAVISVILLE BUILDUP
# DAVISVILLE CAR HOUSE
# DAVISVILLE CARHOUSE
# DAVISVILLE OFFICES
# DAVISVILLE STATION
# DAVISVILLE STATION - B
# DAVISVILLE STATION TO
# DAVISVILLE YARD
# DAVISVILLE YARD / TRAC
# ...

# %%
# put the data into a nice format for mapping
df_replacements = pd.read_csv('/Users/xiaotongshen/Desktop/SDSS-Datathon-2025/python notebooks/exploratory-data-analysis/Transportation-Data/subway-stations.csv', header=None)

# Create a replacement mapping dictionary
replacement_mapping = {
    "OSSINGTON AND LANSDOWN": "N/A",
    "OSSINGTON STATION":"OSSINGTON",
    "OSSINGTON STATON": "OSSINGTON",
    "PAPE STATION": "PAPE",
    "PIONEER VILLAGE STATIO": "PIONEER VILLAGE",
    "QUEEN QUAY STATION": "QUEEN'S PARK",
    "QUEEN STATION": "QUEEN'S PARK",
    "QUEEN'S PARK STATION": "QUEEN'S PARK",
    "QUEEN'S QUAY STATION": "QUEEN'S PARK",
    "QUEENS PARK STATION":"QUEEN'S PARK",
    "QUEENS QUAY (UNION)": "QUEEN'S PARK",
    "QUEENS QUAY ELEAVATOR": "QUEEN'S PARK",
    "QUEENS QUAY ELEVATOR": "QUEEN'S PARK",
    "QUEENS QUAY STATION": "QUEEN'S PARK",
    "QUEENS' QUAY STATION": "QUEEN'S PARK",
    "ROSEDALE STATION": "ROSEDALE",
    "ROYAL YORK AND ISLINGT": "N/A",
    "ROYAL YORK STATION": "ROYAL YORK",
    "ROYAL YORK STATION(APP": "ROYAL YORK",
    "RUNNYMEDE STATION": "RUNNYMEDE",
    "RUSSEL HILL EE - INTRU": "N/A",
    "SCARBOROUGH CENTRE STA": "N/A",
    "SCARBOROUGH CTR STATIO": "N/A",
    "SHEPPARD LINE": "N/A",
    "SHEPPARD STATION": "SHEPPARD-YONGE",
    "SHEPPARD TAIL": "SHEPPARD-YONGE",
    "SHEPPARD WEST - FINCH": "SHEPPARD-YONGE",
    "SHEPPARD WEST - ST CLA": "SHEPPARD-YONGE",
    "SHEPPARD WEST STATION": "SHEPPARD-YONGE",
    "SHEPPARD WYE": "SHEPPARD-YONGE",
    "SHEPPARD YONGE STATION": "SHEPPARD-YONGE",
    "SHEPPARD-YONGE AND ST": "SHEPPARD-YONGE",
    "SHEPPARD-YONGE STATION": "SHEPPARD-YONGE",
    "SHERBOURNE STATION": "SHERBOURNE",
    "SINGLE LINE OPERATIONS": "N/A",
    "SPADINA BD STATION": "SPADINA 2",
    "SPADINA STATION": "N/A", #includes 1, 2, NaN
    "SPADINA YU STATION": "SPADINA 1",
    "SPADINA YUS STATION": "SPADINA 1",
    "ST ANDREW STATION": "ST ANDREW",
    "ST CLAIR - YORK MILLS": "ST CLAIR",
    "ST CLAIR AND UNION STA": "ST CLAIR",
    "ST CLAIR STATION": "ST CLAIR",
    "ST CLAIR WEST STATION": "ST CLAIR WEST",
    "ST GEOGE STATION": "ST GEORGE 1",
    "ST GEORGE - LAWRENCE W": "ST GEORGE 1",
    "ST GEORGE AND WOODBINE": "ST GEORGE 2",
    "ST GEORGE BD STATION": "ST GEORGE 2",
    "ST GEORGE BD/YU STATIO": "ST GEORGE 2", 
    "ST GEORGE STATION": "ST GEORGE 1/2", #has both 1 and 2
    "ST GEORGE YUS STATION": "ST GEORGE 1",
    "ST PATRICK STATION": "ST PATRICK",
    "ST. ANDREW STATION": "ST ANDREW",
    "ST. CLAIR AND SHEPPARD": "N/A",
    "ST. GEORGE STATION": "ST GEORGE 1",
    "SUBWAY CLOSURE BLOOR-D": "N/A",
    "SUBWAY CLOSURE: LAWREN": "N/A",
    "SUBWAY CLOSURE: ST GEO": "N/A",
    "SUBWAY CLOSURE: WARDEN": "N/A",
    "SUBWAY CLOSURE: WEEKEN": "N/A",
    "SUBWAY CLOSURE: WOODBI": "N/A",
    "SUBWAY LINE 1 YONGE -": "N/A",
    "SUBWAY OPS BUILDING": "N/A",
    "SUMMERHILL STATION": "SUMMERHILL",
    "SUMMERHILL STATION TO": "SUMMERHILL",
    "SYSTEM WIDE": "N/A",
    "SYSTEMWIDE": "N/A",
    "TORONTO TRANIST COMMIS": "N/A",
    "TORONTO TRANSIT COMMIS": "N/A",
    "TORONTO TRANSIT CONTRO": "N/A",
    "TRACK LEVEL ACTIVITY": "N/A",
    "UNION": "UNION",
    "UNION - KING": "UNION",
    "UNION AND DOWNSVIEW": "UNION",
    "UNION CENTRE TRACK": "UNION",
    "UNION STATION": "UNION",
    "UNION STATION ( TOWARD": "UNION",
    "UNION STATION (TO KING": "UNION",
    "UNION STATION (TO ST.A": "UNION",
    "UNION STATION (TOWARD": "UNION",
    "UNION STATION (TOWARDS": "UNION",
    "UNION STATION - HUB": "UNION",
    "UNION STATION - KING": "UNION",
    "UNION STATION - NB TO": "UNION",
    "UNION STATION - ST AND": "UNION",
    "UNION STATION BROOKFIE": "UNION",
    "UNION STATION HUB": "UNION",
    "UNION STATION TOWARD K": "UNION",
    "UNION STATION TOWARDS": "UNION",
    "UNION STATION--ST ANDR": "UNION",
    "UNKNOWN LOCATION": "N/A",
    "VARIOUS LOCATION": "N/A",
    "VARIOUS LOCATIONS": "N/A",
    "VAUGHAN MC STATION": "VAUGHAN METROPOLITAN CENTRE",
    "VAUGHAN MC STATION TO": "VAUGHAN METROPOLITAN CENTRE",
    "VICTORIA PARK STATION": "VICTORIA PARK",
    "VICTORIA PARK STATION-": "VICTORIA PARK",
    "VMC - ST CLAIR": "VAUGHAN METROPOLITAN CENTRE",
    "VMC AND FINCH WEST STA": "VAUGHAN METROPOLITAN CENTRE",
    "WARDEN STATION": "WARDEN",
    "WARDEN STATION (LEAVIN": "WARDEN",
    "WEEKEND CLOSURE - WOOD": "N/A",
    "WEEKEND CLOSURE SHEPPA": "N/A",
    "WELBECK EE": "N/A", 
    "WELLESLEY STATION": "WELLESLEY", 
    "WILFRED EE": "N/A",
    "WILFRED EEB": "N/A",
    "WILFRED EMERGENCY EXIT": "N/A",
    "WILSON CAR HOUSE": "WILSON",
    "WILSON CARHOUSE": "WILSON",
    "WILSON HOSTLER": "WILSON",
    "WILSON HOSTLER - 2": "WILSON",
    "WILSON HOSTLER 2": "WILSON",
    "WILSON SOUTH HOSTLER": "WILSON",
    "WILSON STATION": "WILSON",
    "WILSON STATION APPROAC": "WILSON",
    "WILSON TRAINING CENTER": "WILSON",
    "WILSON YARD": "WILSON",
    "WILSON YARD - 26 TRACK": "WILSON",
    "WILSON YARD HOSTLER #2": "WILSON",
    "WILSON YARD- WILSON GA": "WILSON",
    "WISLON STATION": "WILSON",
    "WOODBINE STATION": "WOODBINE",
    "WOODBINE STATION (LEAV": "WOODBINE",
    "YONGE - UNIVERSITY AND": "N/A",
    "YONGE - UNIVERSITY LIN": "N/A",
    "YONGE / UNIVERSITY LIN": "N/A",
    "YONGE AND BLOOR": "BLOOR-YONGE",
    "YONGE AND SHEPPARD": "SHEPPARD-YONGE",
    "YONGE BD STATION": "BLOOR-YONGE",
    "YONGE BD STATION (ON R": "BLOOR-YONGE",
    "YONGE STATION": "N/A",
    "YONGE UNIVERSITY": "N/A",
    "YONGE UNIVERSITY AND B": "BLOOR-YONGE",
    "YONGE UNIVERSITY LINE": "N/A",
    "YONGE UNIVERSITY SPADI": "SPADINA 1", #has line 1 and 1/2
    "YONGE UNIVERSITY SUBWA": "N/A",
    "YONGE UNIVESITY LINE": "N/A",
    "YONGE- UNIVERSITY AND": "N/A",
    "YONGE-UNIVERSITY": "N/A",
    "YONGE-UNIVERSITY & BLO": "BLOOR-YONGE",
    "YONGE-UNIVERSITY AND B": "BLOOR-YONGE",
    "YONGE-UNIVERSITY LINE": "N/A",
    "YONGE-UNIVERSITY SUBWA": "N/A",
    "YONGE-UNIVERSITY-SPADI": "SPADINA 1",
    "YONGE/UNIVERSITY AND B": "BLOOR-YONGE",
    "YONGE/UNIVERSITY/SPADI": "SPADINA 1",
    "YORK MILLS AND EGLINTO": "N/A",
    "YORK MILLS STATION": "YORK MILLS",
    "YORK MILLS STATION - C": "YORK MILLS",
    "YORK MILLS STATION TO": "YORK MILLS",
    "YORK UNIVERSITY STATIO": "YORK UNIVERSITY",
    "YORKDALE STATION": "YORKDALE",
    "YOUNG UNIVERSITY LINE": "N/A",
    "YOUNGE-UNIVERSITY-SPAD": "SPADINA 1",
    "YU & BD LINES": "N/A",
    "YU- YONGE-UNIVERSITY S": "N/A",
    "YU-ST CLAIR STATION TO": "N/A"
}

# Iterate through the DataFrame to populate the mapping
for index, row in df_replacements.iterrows():
    # Split the string by the last occurrence of ' - '
    parts = row[0].rsplit(' - ', 1)  # Split from the right, only once
    if len(parts) == 2:  # Ensure there are exactly two parts
        original, new = parts  # Unpack the parts
        replacement_mapping[original.strip()] = new.strip()  # Add to the dictionary
# Display the replacement mapping
print(replacement_mapping)

df_cleaned['Station'] = df_cleaned['Station'].replace(replacement_mapping)
print(df_cleaned)

# remove n/a or na values
df_cleaned = df_cleaned[~df_cleaned['Station'].isin(['N/A', 'NA'])]
print(df_cleaned)
# Out:
# {'OSSINGTON AND LANSDOWN': 'N/A', 'OSSINGTON STATION': 'OSSINGTON', 'OSSINGTON STATON': 'OSSINGTON', 'PAPE STATION': 'PAPE', 'PIONEER VILLAGE STATIO': 'PIONEER VILLAGE', 'QUEEN QUAY STATION': "QUEEN'S PARK", 'QUEEN STATION': "QUEEN'S PARK", "QUEEN'S PARK STATION": "QUEEN'S PARK", "QUEEN'S QUAY STATION": "QUEEN'S PARK", 'QUEENS PARK STATION': "QUEEN'S PARK", 'QUEENS QUAY (UNION)': "QUEEN'S PARK", 'QUEENS QUAY ELEAVATOR': "QUEEN'S PARK", 'QUEENS QUAY ELEVATOR': "QUEEN'S PARK", 'QUEENS QUAY STATION': "QUEEN'S PARK", "QUEENS' QUAY STATION": "QUEEN'S PARK", 'ROSEDALE STATION': 'ROSEDALE', 'ROYAL YORK AND ISLINGT': 'N/A', 'ROYAL YORK STATION': 'ROYAL YORK', 'ROYAL YORK STATION(APP': 'ROYAL YORK', 'RUNNYMEDE STATION': 'RUNNYMEDE', 'RUSSEL HILL EE - INTRU': 'N/A', 'SCARBOROUGH CENTRE STA': 'N/A', 'SCARBOROUGH CTR STATIO': 'N/A', 'SHEPPARD LINE': 'N/A', 'SHEPPARD STATION': 'SHEPPARD-YONGE', 'SHEPPARD TAIL': 'SHEPPARD-YONGE', 'SHEPPARD WEST - FINCH': 'SHEPPARD-YONGE', 'SHEPPARD WEST - ST CLA':
# ...

# %% [markdown]
# # removes unnessecary stuff in line column
# remove_lines = ["SRT", "109 RANEE", "TRACK LEVEL ACTIVITY", "YU/BD/SHP"]
# df = df[~df["Line"].isin(remove_lines)]
# df["Line"].value_counts()

# %%
# maps lines
line_mapping = {
    "YU": "Line 1",
    "BD": "Line 2",
    "SHP": "Line 4",
    "YU/BD": "Line 1/2",
    "YU/ BD": "Line 1/2",
    "YUS/BD": "Line 1/2",
    "YUS": "Line 1",
    "YU / BD": "Line 1/2",
    "YU & BD": "Line 1/2",
    "BD/YU": "Line 1/2",
    "BD/ YU": "Line 1/2",
    "BD/ YUS": "Line 1/2",
    "SHEP": "Line 4",
    "ONGE-UNIVERSITY AND BL": "Line 1/2",
    "LINE 1": "Line 1",
    "BLOOR DANFORTH": "Line 2",
    "BD / YU": "Line 1/2"
}
df.loc[:, "Line"] = df["Line"].replace(line_mapping)

# %%
df_cleaned.to_csv('./Transportation-Data/subway-data-cleaned.csv', index=False)
